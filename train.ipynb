# %% [markdown]
# # Training the model to predict the potential function given the memory function and the integrated path.
#
# We are going to use a neural network to predict the potential function based on the memory function and the integrated path. The input to the model will be a the coordinates of the memory function and the integrated path, while the output will be the potential function. The parameters are as follows:
#
# 1) Input: 4 features (x_memory, y_memory, x_integrated, y_integrated)
# 2) Output: 2 features (x_potential, y_potential)
# 3) Loss function: Mean Squared Error (MSE)
# 4) Optimizer: Adam
# 5) Number of epochs: 100
#
# An 80-20 split will be used for training and validation. The model will be trained on the training set and evaluated on the validation set. The performance of the model will be measured using the Mean Squared Error (MSE) metric.

# %%
import
